# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from tqdm import tqdm

from src.utils import get_trajectories_df, get_user_ids, get_activities_df, get_labeled_ids
from src.utils.connection import DbConnector
from pprint import pprint

# %%
connection = DbConnector()
client = connection.client
db = connection.db

collection = db["ActivityCollection"]
documents = collection.find({})

pprint(documents[0])
    
connection.close_connection()
# Out:
# You are connected to the database: mongodb
# -----------------------------------------------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/mathiasraa/Desktop/ntnu/tdt4225-mongodb/notebooks/data.ipynb Cell 3 line 8
#       <a href='vscode-notebook-cell:/Users/mathiasraa/Desktop/ntnu/tdt4225-mongodb/notebooks/data.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> collection = db["ActivityCollection"]
#       <a href='vscode-notebook-cell:/Users/mathiasraa/Desktop/ntnu/tdt4225-mongodb/notebooks/data.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> documents = collection.find({})
# ----> <a href='vscode-notebook-cell:/Users/mathiasraa/Desktop/ntnu/tdt4225-mongodb/notebooks/data.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> pprint(documents[0])
#      <a href='vscode-notebook-cell:/Users/mathiasraa/Desktop/ntnu/tdt4225-mongodb/notebooks/data.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> connection.close_connection()
# ...

# %%
trajectories_df = get_activities_df("000")


trajectories_df.head(50)
# Out:
#        start_date_time       end_date_time transportation_mode user_id  \
# 0  2009-04-12 07:33:03 2009-04-12 17:24:59                None     000
# 1  2009-05-10 02:02:06 2009-05-10 06:20:11                None     000
# 2  2008-12-01 11:18:27 2008-12-01 11:35:15                None     000
# 3  2009-06-21 10:14:07 2009-06-21 14:47:12                None     000
# 4  2008-12-11 12:14:32 2008-12-11 12:24:32                None     000
# 5  2009-06-29 01:16:30 2009-06-29 11:13:12                None     000
# 6  2009-05-09 18:16:36 2009-05-09 18:30:36                None     000
# 7  2009-07-03 00:28:00 2009-07-03 08:37:23                None     000
# 8  2009-06-07 07:52:55 2009-06-07 09:46:03                None     000
# 9  2009-06-11 22:12:04 2009-06-11 22:34:54                None     000
# 10 2009-04-26 17:55:13 2009-04-26 18:08:13                None     000
# 11 2008-11-13 03:46:08 2008-11-13 14:11:31                None     000
# ...

# %%
"120090412073303.0001"[:10]
# Out:
# '1200904120'

# %%
activities = get_activities_df("104")
activities
# Out:
#        start_date_time       end_date_time transportation_mode user_id  \
# 0  2007-11-30 09:59:00 2007-11-30 10:38:00                 bus     104
# 1  2007-11-30 12:40:00 2007-11-30 13:18:00                 bus     104
# 2  2007-12-02 12:27:00 2007-12-02 12:57:00                 bus     104
# 3  2007-12-02 13:00:00 2007-12-02 13:25:00                 bus     104
# 4  2007-12-04 07:45:00 2007-12-04 08:30:00                 car     104
# ..                 ...                 ...                 ...     ...
# 83 2008-12-27 03:47:00 2008-12-27 04:11:00                 bus     104
# 84 2008-12-27 10:19:00 2008-12-27 11:40:00                 bus     104
# 85 2008-12-30 03:03:00 2008-12-30 03:22:00                 bus     104
# 86 2008-12-30 05:00:00 2008-12-30 05:17:00                 bus     104
# 87 2008-12-31 13:59:00 2008-12-31 14:55:00                taxi     104
#
#                 id
# 0   20071130095900
# 1   20071130124000
# 2   20071202122700
# 3   20071202130000
# ...

# %%
trajectories = get_trajectories_df("104")
trajectories
# Out:
# /Users/mathiasraa/Desktop/ntnu/tdt4225-mysql/src/utils/data_load.py:94: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#       latitude   longitude altitude           date_time     activity_id
# 0    39.966107  116.340690        0 2008-01-01 09:42:31  20080101094000
# 1    39.966100  116.341192        0 2008-01-01 09:42:34  20080101094000
# 2    39.966090  116.341647        0 2008-01-01 09:42:37  20080101094000
# 3    39.966098  116.342063        0 2008-01-01 09:42:40  20080101094000
# 4    39.966103  116.342487        0 2008-01-01 09:42:43  20080101094000
# ..         ...         ...      ...                 ...             ...
# 317  39.917292  116.309435        0 2008-03-28 09:40:01  20080328084200
# ...
